# %% [markdown]
# <a href="https://colab.research.google.com/github/singhraj00/Python-Interview-Question/blob/main/list_coding_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # reverse list without using reverse()

# %%
a = [10,20,30,40,50]
print(a[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
res = []
for i in a:
  res.insert(0,i)
print(res)
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# # Remove duplicates from list

# %%
b = [44,11,23,44,55,11]

seen = set()
result = []

for i in b:
  if i not in seen:
    seen.add(i)
    result.append(i)

print(result)
# Out:
# [44, 11, 23, 55]

# %%
print(list(set(b)))
# Out:
# [11, 44, 55, 23]

# %% [markdown]
# # find max & min elements from list

# %%
c = [34,12,67,45,11]

min_val = c[0]
max_val = c[0]

for num in c:
  if num>max_val:
    max_val=num
  elif num<min_val:
    min_val = num

print(min_val,max_val)
# Out:
# 11 67

# %% [markdown]
# # check list is palindrome or not

# %%
lst = [1,2,3,2,1]

if lst == lst[::-1]:
  print('palindrome')
else:
  print('not palindrome')
# Out:
# palindrome

# %% [markdown]
# # find frequency of each element

# %%
freq = {}
for i in lst:
  freq[i]=freq.get(i,0)+1
print(freq)
# Out:
# {1: 2, 2: 2, 3: 1}

# %% [markdown]
# # sort list without using sort()

# %%
lst = [89,21,33,46,17,12]

for i in range(len(lst)):
  for j in range(i+1,len(lst)):
    if lst[i]>lst[j]:
      lst[i],lst[j]=lst[j],lst[i]

print(lst)
# Out:
# [12, 17, 21, 33, 46, 89]

# %% [markdown]
# # merge two list

# %%
a = [1,2,3]
b = [4,5,6]

print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# # find common elements from list

# %%
a = [1,2,3]
b = [3,4,5]

print(list(set(a)&set(b)))
# Out:
# [3]

# %% [markdown]
# # convert list of tuple to dict

# %%
lst = [(1,'one'),(2,'two'),(3,'three')]

d={}
for k,v in lst:
  d[k]=v

print(d)
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %% [markdown]
# # flatten nested list

# %%
lst = [1,2,3,[4,5],6,7]

flat = [x for sub in lst for x in (sub if isinstance(sub,list) else [sub])]

print(flat)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
flat = []

for num in lst:
  if isinstance(num,list):
    flat.extend(num)
  else:
    flat.append(num)

print(flat)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# # Square of each element

# %%
lst = [1,2,3,4,5]

sqr = [i*i for i in lst]

sqr
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# # find second largest number

# %%
lst = [10,20,4,45,99]

first=second=float('-inf')

for i in lst:
  if i>first:
    second=first
    first=i
  elif i>second and i!=first:
    second=i

print(second)
# Out:
# 45

# %% [markdown]
# # rotate list by k

# %%
lst = [1,2,3,4,5]
k = 2

print(lst[k:]+lst[:k])
# Out:
# [3, 4, 5, 1, 2]

# %% [markdown]
# # check list contains only number

# %%
lst = [1,2,3,'a']
print(all(isinstance(x,int) for x in lst))
# Out:
# False

# %% [markdown]
# # find index of element without using index()

# %%
lst = [10,20,30,40,50]
x=30
pos=-1

for i in range(len(lst)):
  if lst[i]==x:
    pos=i
    break

print(pos)
# Out:
# 2

# %% [markdown]
# ## List compherension : get even numbers

# %%
lst = [11,22,33,44,77,99]
even_num = [x for x in lst if x%2==0]
even_num
# Out:
# [22, 44]

# %% [markdown]
# ## convert list to string

# %%
lst = ['my','name','is','raj']
res = " ".join(lst)
res
# Out:
# 'my name is raj'

# %% [markdown]
# # find all pairs whose sum is K

# %%
def two_sum(arr,target):
  seen = {}
  for i,num in enumerate(arr):
    comp = target-num
    if comp in seen:
      return [seen[comp],i]
    seen[num]=i
  return []

two_sum([2,5,7,11],9)
# Out:
# [0, 2]

# %% [markdown]
# # Remove empty list inside list

# %%
lst = [1,[],2,[],3,[]]

res = [i for i in lst if i!=[]]
res
# Out:
# [1, 2, 3]

# %% [markdown]
# # Replace List element at specified index

# %%
lst = [10,20,30,40]
lst[1]=15
lst
# Out:
# [10, 15, 30, 40]

# %% [markdown]
# # sort list dict by keys

# %%
lst = [{'age':23},{'age':20},{'age':25}]
res = sorted(lst,key=lambda x:x['age'])
res
# Out:
# [{'age': 20}, {'age': 23}, {'age': 25}]

# %% [markdown]
# ## find list of element > average

# %%
lst = [10,20,30,40,50]
avg = sum(lst)/len(lst)

res = [x for x in lst if x>avg]
res
# Out:
# [40, 50]

# %% [markdown]
# # split list into chunks

# %%
lst = [1,2,3,4,5,6,7]
n = 3

chunks = [lst[i:i+n] for i in range(0,len(lst),n)]
chunks
# Out:
# [[1, 2, 3], [4, 5, 6], [7]]

# %% [markdown]
# # remove all occurence of value

# %%
lst = [1,2,2,2,3,4,5]
val = 2

res = [x for x in lst if x!=val]
res
# Out:
# [1, 3, 4, 5]

# %% [markdown]
# # find missing number in range

# %%
lst = [1,2,3,4,6,7,8]
full = range(lst[0],lst[-1]+1)

missing = [x for x in full if x not in lst]
missing
# Out:
# [5]

# %% [markdown]
# # find intersection without set

# %%
a = [1,2,3,4]
b = [3,4,5,6]

res = [x for x in a if x in b]
res
# Out:
# [3, 4]

# %% [markdown]
# ## all elements are same or not

# %%
lst = [5,5,5,5]
print(len(set(lst))==1)
# Out:
# True

# %% [markdown]
# ## remove negative number from list

# %%
lst = [10,20,-19,89,-76]
res = [x for x in lst if x>0]
res
# Out:
# [10, 20, 89]

# %% [markdown]
# # replace negative with 0

# %%
for i in range(len(lst)):
  if lst[i]<0:
    lst[i]=0

print(lst)
# Out:
# [10, 20, 0, 89, 0]

# %% [markdown]
# ## MCQ

# %%
a = [1,2,3]
b=a
b.append(4)
print(a)

# %%
a = [1,2,3]
b= a[:]
b.append(4)
print(a,b)
# Out:
# [1, 2, 3] [1, 2, 3, 4]

# %%
lst = [1,2,3,2,4,2]
print([i for i,x in enumerate(lst) if x==2])
# Out:
# [1, 3, 5]

# %%
lst = [1,2,3,4]
lst[1:3]=[99,100]
lst
# Out:
# [1, 99, 100, 4]

# %%
a = [1,[2,3],5]
a[1].append(4)
a
# Out:
# [1, [2, 3, 4], 5]

# %%
# reverse list using recursion
def rev(lst):
  if len(lst)==0:
    return []
  return [lst[-1]]+rev(lst[:-1])
rev(lst)
# Out:
# [4, 100, 99, 1]

# %%
## multiply all elements
from functools import reduce
lst = [1,2,3,4,5]
print(reduce(lambda x,y:x*y,lst))
# Out:
# 120

# %%
# find duplicates using list compherencion
lst = [1,2,3,2,1,3,4]
dup = list(set([x for x in lst if lst.count(x)>1]))
dup
# Out:
# [1, 2, 3]

# %%
# convert list to tuple
lst = [10,20,30]
print(tuple(lst))
# Out:
# (10, 20, 30)

# %%
# merge two dict
a = {1:'x'}
b = {2:'y'}

print({**a,**b})
# Out:
# {1: 'x', 2: 'y'}

# %%
# check string is anaggram
a = 'listen'
b = 'silent'

print(sorted(a)==sorted(b))
# Out:
# True

# %%
# reverse each word in string
s = 'hello world'
res = " ".join([w[::-1] for w in s.split()])
res
# Out:
# 'olleh dlrow'

# %%
# convert two list to dict
keys = ['a','b','c']
values = [1,2,3]

print(dict(zip(keys,values)))
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
# sort list of tuple by second value
lst = [(1,4),(3,1),(5,3)]
res = sorted(lst,key=lambda x:x[1])
res
# Out:
# [(3, 1), (5, 3), (1, 4)]

# %%
# count frequecy of char
s = 'banana'

freq={}

for ch in s:
  freq[ch]=freq.get(ch,0)+1

freq
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %%
# check if list is subset of another
a = [1,2]
b = [1,2,3,4]

print(all(x in b for x in a))
# Out:
# True

# %%
# convert tuple - list - modify - tuple
t = (1,2,3)
lst = list(t)
lst.append(4)
t = tuple(lst)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
# remove keys from dict safely
d = {'a':1,'b':2}
d.pop('c',None)
print(d)
# Out:
# {'a': 1, 'b': 2}

# %%
# flatten list of dict values
lst = [{'a':1},{'b':2},{'c':3}]
res = [v for d in lst for v in d.values()]
res
# Out:
# [1, 2, 3]

# %%
# check list is palindrome
lst = [1,2,3,2,1]
print(lst==lst[::-1])
# Out:
# True

# %%
# find common keys in two dict
a = {'x':1,'y':2}
b = {'y':3,'z':4}

print(a.keys() & b.keys())
# Out:
# {'y'}

# %%
sentence = 'my name is raj'
" ".join(w[::-1] for w in sentence.split())
# Out:
# 'ym eman si jar'

# %%
lst = [10,5,20,8]

first=second=float('-inf')

for num in lst:
  if num>first:
    second=first
    first=num
  elif num>second and num!=first:
    second=num

print(second)
# Out:
# 10

# %%
lst = [(1,'a'),(2,'b'),(3,'c')]
d = {}
for k,v in lst:
  d[k]=v

print(d)
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
def two_sum(arr,target):
  seen={}
  for i,num in enumerate(arr):
    comp = target-num
    if comp in seen:
      return [seen[comp],i]
    seen[num]=i
  return []

two_sum([2,5,7,11],9)
# Out:
# [0, 2]

# %%
a = 'listen'
b = 'silent'

print(sorted(a)==sorted(b))
# Out:
# True

# %%
lst = [1,[2,[3,4],5],6]
res=[]
for i in lst:
  if isinstance(i,list):
    res.extend(i)
  else:
    res.append(i)

res
# Out:
# [1, 2, [3, 4], 5, 6]

# %%
s = 'banana'
freq={}

for ch in s:
  freq[ch] = freq.get(ch,0)+1

freq
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %%
lst = [1,2,3,2,1]

seen = set()
result=[]

for num in lst:
  if num not in seen:
    seen.add(num)
    result.append(num)

result
# Out:
# [1, 2, 3]

# %%
lst = [1,2,3,4,5]
k=2

print(lst[k:]+lst[:k])
# Out:
# [3, 4, 5, 1, 2]

# %%
lst = [1,2,3,2,1]
print(lst==lst[::-1])
# Out:
# True

# %%
def flatten(arr):
  res=[]
  for num in arr:
    if isinstance(num,list):
      res.extend(flatten(num))
    else:
      res.append(num)
  return res

flatten([1,[2,[3,4],5],6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def rev_list_inplace(arr):
  left,right=0,len(arr)-1
  while left<right:
    arr[left],arr[right]=arr[right],arr[left]
    left+=1
    right-=1
  return arr

rev_list_inplace([1,2,3,4])
# Out:
# [4, 3, 2, 1]

# %%
lst = [1,2,3,4,5]
lst[:] = lst[::-1]
lst
# Out:
# [5, 4, 3, 2, 1]

# %%
lst.reverse()
lst
# Out:
# [1, 2, 3, 4, 5]
